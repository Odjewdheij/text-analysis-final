# %% [markdown]
# <a href="https://colab.research.google.com/github/Odjewdheij/text-analysis-final/blob/text-analysis-final/final_project_shuyuwu_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Measuring News Sentiment and Policy Topic Exposure for Major Firms**
#
# ## 1. Research Question and Policy Relevance
#
# Financial news plays a central role in shaping how markets and the public interpret developments in the technology, financial, and energy sectors—especially during a period defined by rapid AI expansion, shifting macroeconomic conditions, and volatile energy markets. This project analyzes seven large, systemically important firms: **Apple (AAPL), Microsoft (MSFT), NVIDIA (NVDA), Tesla (TSLA), JPMorgan Chase (JPM), Goldman Sachs (GS), and Exxon Mobil (XOM).**
#
# **Research question:**
# *How does news sentiment vary across these firms, and how strongly are their news narratives associated with three policy-relevant themes: macroeconomic policy, AI/technology policy, and energy/commodity policy?*
#
# This question matters for policymakers for several reasons:
#
# * **Macroeconomic policy:**
#   Sentiment toward financial firms influences expectations about monetary policy, financial stability, and credit conditions.
#
# * **AI and technology governance:**
#   Negative or skeptical sentiment around tech companies—especially NVIDIA, Microsoft, and Tesla—may indicate public concerns about an *AI bubble*, data governance risk, or uncertainty about future regulation.
#
# * **Energy and climate policy:**
#   News coverage of energy firms like ExxonMobil reflects ongoing debates around energy security, carbon policy, and commodity-cycle volatility.
#
# To answer this question, the project combines:
#
# 1. **API-based financial news collection**,
# 2. **web scraping of full article text**,
# 3. **VADER sentiment scoring**, and
# 4. **a dictionary-based topic-exposure model** measuring coverage related to *macro*, *AI*, and *energy* themes.

# %%
# !pip -q install requests beautifulsoup4 lxml yfinance nltk plotly kaleido

import re
from collections import Counter
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import requests
from bs4 import BeautifulSoup
import yfinance as yf

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import plotly.express as px
import plotly.io as pio

# Download required NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('vader_lexicon')
nltk.download('punkt_tab')

# Display options for pandas
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)

# List of tickers analyzed in this project
TICKERS = ["AAPL", "MSFT", "NVDA", "JPM", "GS", "XOM", "TSLA"]

print("✅ Imports and NLTK resources ready.")
print(f"✅ We will collect financial news for {len(TICKERS)} tickers:", TICKERS)
# Out:
# ✅ Imports and NLTK resources ready.
# ✅ We will collect financial news for 7 tickers: ['AAPL', 'MSFT', 'NVDA', 'JPM', 'GS', 'XOM', 'TSLA']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## 2. Data collection: building a clean financial news corpus
#
# My goal in this step is to build a high-quality news dataset for seven major firms
# (Apple, Microsoft, NVIDIA, Tesla, JPMorgan, Goldman Sachs, and Exxon Mobil).
#
# Instead of taking every raw URL from the API, I use a three-stage pipeline:
#
# 1. **Query design** – search by both company name and ticker (e.g., `"Apple" OR AAPL`).
# 2. **Metadata-level filtering** – remove paywalled/aggregator domains, non-news pages, and ad-like content before scraping.
# 3. **Body-text relevance filtering** – after scraping, keep only articles whose full text is long enough and clearly related to the target firm based on a finance-specific dictionary.

# %% [markdown]
# ### 2.1 Query design: company name + ticker
#
# Many financial articles mention companies by name, ticker, or both.
# To capture these systematically, I define a set of query keywords for each firm
# —for example `"Apple" OR AAPL` or `"Goldman Sachs" OR GS`—and pass this combined query to the NewsAPI.

# %%
import re
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Mapping from ticker to the keywords used in the NewsAPI query
TICKER_KEYWORDS = {
    "AAPL": ["Apple", "AAPL"],
    "MSFT": ["Microsoft", "MSFT"],
    "NVDA": ["NVIDIA", "NVDA"],
    "TSLA": ["Tesla", "TSLA"],
    "JPM":  ["JPMorgan", "JPM"],
    "GS":   ["Goldman Sachs", "GS"],
    "XOM":  ["Exxon Mobil", "XOM"],
}

NEWSAPI_KEY = "022fb134ae0549258ae4a52d89a994f4"   # <-- put your own key
NEWS_URL = "https://newsapi.org/v2/everything"

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/122.0.0.0 Safari/537.36"
    )
}

def build_query(keywords):
    """
    Build a NewsAPI query string, e.g. ["Apple", "AAPL"] -> '"Apple" OR AAPL'.
    This lets me search for both the company name and the ticker.
    """
    parts = []
    for kw in keywords:
        if " " in kw:
            parts.append(f'"{kw}"')   # quote multi-word names
        else:
            parts.append(kw)
    return " OR ".join(parts)

# %% [markdown]
# ### 2.2 Metadata-level filtering: removing low-value and ad-like content
#
# Raw API results contain many URLs that are not useful for text analysis:
#
# - Paywalled or low-value aggregators (e.g., **The Fly**, **Biztoc**, **Slashdot**).
# - Non-news pages such as driver downloads, manuals, app pages, and shopping deals.
# - Articles with missing URLs.
#
# Before scraping any HTML, I:
#
# 1. Drop rows with missing URLs.
# 2. Exclude known low-value domains: `thefly.com`, `biztoc.com`, `slashdot.org`.
# 3. Remove titles and URLs that contain obvious non-news or ad-like keywords such as
#    `driver`, `download`, `manual`, `support`, `deal/deals`, `sale`, `discount`, `promo`, or `sponsored`.
# 4. Deduplicate by a normalized title string so repeated headlines are only counted once.
#
# I also print article counts at each step to see where the sample shrinks.

# %%
# Non-news / ad-like keywords in titles and URLs
BAD_TITLE_KEYWORDS = [
    "driver", "drivers", "download", "downloads",
    "manual", "user guide", "installation", "install",
    "setup", "how to", "faq", "support page", "release notes",
    "patch notes", "coupon", "deal", "deals",
    # ad-like words
    "sponsored", "promotion", "promo", "advertisement",
    "limited time", "sale", "discount"
]

BAD_URL_KEYWORDS = [
    "support", "download", "drivers", "manual",
    "help", "faq", "store", "shop", "community", "forum",
    "deals", "coupon"
]

BAD_TITLE_PAT = re.compile("|".join(re.escape(k) for k in BAD_TITLE_KEYWORDS))
BAD_URL_PAT   = re.compile("|".join(re.escape(k) for k in BAD_URL_KEYWORDS))

# Domains to exclude completely (paywalls / aggregators)
BAD_DOMAINS = ["thefly.com", "biztoc.com", "slashdot.org"]


def fetch_candidates_for_ticker(ticker, keywords, max_pages=10, page_size=10):
    """
    Fetch up to max_pages * page_size candidate articles for a given ticker.

    Steps:
      1. Query NewsAPI using both company name and ticker.
      2. Drop rows with missing URLs.
      3. Remove paywalled / low-value domains (thefly.com, biztoc.com, slashdot.org).
      4. Remove obvious non-news or ad-like pages by title and URL keywords.
      5. Deduplicate by normalized title.

    I print the number of articles after each filter so it is clear
    why some tickers end up with fewer usable items.
    """
    all_records = []
    query = build_query(keywords)

    print(f"\n🔎 Fetching metadata for {ticker} with query: {query}")

    for page in range(1, max_pages + 1):
        params = {
            "q": query,
            "language": "en",
            "pageSize": page_size,
            "page": page,
            "sortBy": "publishedAt",
            "apiKey": NEWSAPI_KEY,
            "searchIn": "title,description,content",
        }

        resp = requests.get(NEWS_URL, params=params)
        print(f"  Page {page} status:", resp.status_code)
        data = resp.json()
        articles = data.get("articles", [])
        if not articles:
            break

        for article in articles:
            title = (article.get("title") or "").strip()
            desc = article.get("description") or ""
            url = article.get("url") or ""
            published_at = article.get("publishedAt") or ""
            source_name = ""
            if isinstance(article.get("source"), dict):
                source_name = article["source"].get("name", "")

            all_records.append({
                "ticker": ticker,
                "source_name": source_name,
                "title": title,
                "description": desc,
                "url": url,
                "publishedAt": published_at,
            })

        # If fewer than page_size results, we are likely at the end of the result set
        if len(articles) < page_size:
            break
        time.sleep(0.7)  # be polite to the API

    if not all_records:
        print(f"⚠️ No articles found for {ticker}")
        return pd.DataFrame()

    df = pd.DataFrame(all_records)
    print(f"  Raw API articles: {len(df)}")

    # Drop missing URLs
    df = df.dropna(subset=["url"])
    print(f"  After dropping missing URLs: {len(df)}")

    # Normalize for filtering
    df["title_norm"]   = df["title"].str.lower().str.strip()
    df["title_lower"]  = df["title"].str.lower()
    df["url_lower"]    = df["url"].str.lower()
    df["source_lower"] = df["source_name"].str.lower()

    # Filter 0: remove BAD_DOMAINS (The Fly, Biztoc, Slashdot)
    mask_bad_domain = pd.Series(False, index=df.index)
    for dom in BAD_DOMAINS:
        root = dom.split(".")[0]
        mask_bad_domain |= df["url_lower"].str.contains(dom, na=False)
        mask_bad_domain |= df["source_lower"].str.contains(root, na=False)
    df = df[~mask_bad_domain].copy()
    print(f"  After removing bad domains: {len(df)}")

    # Filter 1: remove obvious non-news / ad-like pages by title and URL
    mask_bad_title = df["title_lower"].str.contains(BAD_TITLE_PAT, na=False)
    mask_bad_url   = df["url_lower"].str.contains(BAD_URL_PAT, na=False)
    df = df[~(mask_bad_title | mask_bad_url)].copy()
    print(f"  After removing non-news/ad-like pages: {len(df)}")

    # Filter 2: deduplicate by normalized title
    df = df.drop_duplicates(subset=["title_norm"], keep="first")
    print(f"  After title deduplication: {len(df)}")

    return df

# %% [markdown]
# ### 2.3 Scraping and body-text relevance filtering
#
# Title keywords are too strict: many good articles mention the firm mainly in the body,
# especially for analyst commentary and market summaries.
#
# So instead of filtering by title, I scrape each candidate URL and apply a **body-text relevance test**:
#
# 1. Extract all `<p>` tags and join them into a single string.
# 2. Require at least **250 characters** and at least **20 unique words** (to avoid empty or trivial pages).
# 3. Use a firm-specific **industry dictionary** (e.g., “iPhone”, “Mac”, “AAPL” for Apple; “GPU”, “chip”, “AI” for NVIDIA) and require at least **two matches** in the article text.
#
# For each ticker, I iterate through candidates and stop once I have **up to 30 valid, relevant articles**.

# %%
# Firm- and industry-specific dictionaries for body-text relevance
INDUSTRY_DICT = {
    "AAPL": ["apple", "iphone", "ipad", "tim cook", "aapl"],
    "MSFT": ["microsoft", "azure", "office", "msft"],
    "NVDA": ["nvidia", "gpu", "gpus", "chip", "chips", "ai", "semiconductor", "nvda"],
    "TSLA": ["tesla", "ev", "electric vehicle", "autopilot", "elon musk", "tsla"],
    "JPM":  ["jpmorgan", "jpm", "bank", "loan", "trading", "finance"],
    "GS":   ["goldman", "goldman sachs", "gs", "investment bank", "trading", "wall street"],
    "XOM":  ["exxon", "exxon mobil", "xom", "oil", "gas", "energy", "crude"],
}


def scrape_article_text(url):
    """
    Scrape a single article and return the concatenated text from all <p> tags.
    Returns an empty string on failure.
    """
    try:
        r = requests.get(url, headers=HEADERS, timeout=15)
        if r.status_code != 200:
            print(f"  ⚠️ Failed {r.status_code}: {url}")
            return ""
        soup = BeautifulSoup(r.text, "html.parser")
        paras = [p.get_text(strip=True) for p in soup.find_all("p")]
        return " ".join([p for p in paras if p])
    except Exception as e:
        print(f"  ⚠️ Scrape error: {e}")
        return ""


def body_relevant(text, ticker):
    """
    Determine if an article is relevant based on its body text.
    Conditions:
      - length >= 250 characters
      - at least 20 unique word tokens
      - at least 2 matches from the company/industry dictionary
    """
    if not text or len(text) < 250:
        return False

    tokens = re.findall(r"[a-zA-Z]+", text.lower())
    if len(set(tokens)) < 20:
        return False

    dict_words = INDUSTRY_DICT.get(ticker, [])
    lower_text = text.lower()
    matches = sum(word in lower_text for word in dict_words)

    return matches >= 2

# %% [markdown]
# For each ticker, I now:
#
# 1. Fetch a large pool of filtered candidates (up to 10 × 10 = 1,00 items).
# 2. Scrape them one by one.
# 3. Keep only those that pass the body-text relevance test.
# 4. Stop when I reach **up to 30 valid articles** per firm, and then save results to CSV.
# Finally, I combine everything into a single `news_df` dataset.

# %%
TARGET_PER_TICKER = 30   # desired number of valid articles per company

all_results = []

for tkr in TICKERS:
    keywords = TICKER_KEYWORDS[tkr]
    time.sleep(0.8)

    # Step A: fetch candidate metadata (already filtered & deduplicated)
    df_candidates = fetch_candidates_for_ticker(
        tkr,
        keywords,
        max_pages=10,
        page_size=100
    )
    if df_candidates.empty:
        continue

    print(f"📰 Scraping articles for {tkr} until we reach {TARGET_PER_TICKER} valid pieces ...")

    valid_rows = []
    for i, row in df_candidates.reset_index(drop=True).iterrows():
        if len(valid_rows) >= TARGET_PER_TICKER:
            break

        url = row["url"]
        print(f"  ({i+1}/{len(df_candidates)}) {url}")
        text_i = scrape_article_text(url)

        if not body_relevant(text_i, tkr):
            print("    ⏭ Skipped: not relevant or too short")
            continue

        row_dict = row.to_dict()
        row_dict["scraped_text"] = text_i
        row_dict["scraped_len"]  = len(text_i)
        valid_rows.append(row_dict)

        time.sleep(1.0)  # be polite to host servers

    df_valid = pd.DataFrame(valid_rows)
    print(f"✅ {tkr}: collected {len(df_valid)} valid scraped articles.")

    df_valid.to_csv(f"results_{tkr}.csv", index=False)
    all_results.append(df_valid)

# Combine across tickers and defensively deduplicate
if all_results:
    news_df = pd.concat(all_results, ignore_index=True)
    news_df["title_norm"] = news_df["title"].str.lower().str.strip()
    news_df = news_df.drop_duplicates(subset=["ticker", "title_norm"], keep="first")
    print("\n✅ Final news_df after global dedup and filters:", news_df.shape)
else:
    news_df = pd.DataFrame()
    print("⚠️ No valid data collected for any ticker.")

from IPython.display import display
display(news_df[["ticker","source_name","title","scraped_len"]].head(10))
# Out:
# 🔎 Fetching metadata for AAPL with query: Apple OR AAPL
#   Page 1 status: 200
#   Raw API articles: 95
#   After dropping missing URLs: 95
#   After removing bad domains: 83
#   After removing non-news/ad-like pages: 74
#   After title deduplication: 74
# 📰 Scraping articles for AAPL until we reach 30 valid pieces ...
#   (1/74) https://bleedingcool.com/tv/five-ways-netflix-buying-warner-bros-could-change-aew/
#     ⏭ Skipped: not relevant or too short
#   (2/74) https://hiphopwired.com/2936720/lebron-james-selfless-pass-ends-one-of-the-greatest-records-in-nba-history/
#   (3/74) https://9to5mac.com/2025/12/05/critics-choice-awards-apple-tv-nominations/
#     ⏭ Skipped: not relevant or too short
#   (4/74) https://www.mmafighting.com/ufc/459811/ufc-323-preview-show-can-petr-yan-give-merab-dvalishvili-sad-ending-to-historic-year
#     ⏭ Skipped: not relevant or too short
#   (5/74) https://www.cinemablend.com/interviews/elsbeth-scored-awards-nominations-after-switching-categories-carrie-preston-deserves-hype-season-3-gotcha
#     ⏭ Skipped: not relevant or too short
#   (6/74) https://pypi.org/project/aule-attention/0.2.0/
#     ⏭ Skipped: not relevant or too short
#   (7/74) https://pypi.org/project/aule-attention/
#     ⏭ Skipped: not relevant or too short
#   (8/74) https://www.lifesciencesworld.com/how-do-you-clean-a-second-hand-aquarium/
#     ⏭ Skipped: not relevant or too short
#   (9/74) https://www.kcci.com/article/iowa-state-football-coach-jimmy-rogers-replace-matt-campbell-report/69649101
#     ⏭ Skipped: not relevant or too short
#   (10/74) https://www.yankodesign.com/2025/12/05/this-concept-headset-was-grown-by-code-instead-of-designed-by-humans/
#     ⏭ Skipped: not relevant or too short
#   (11/74) https://www.pymnts.com/apple/2025/dozens-of-apple-employees-have-moved-to-openai-and-meta-in-recent-months/
#   (12/74) https://www.forbes.com/sites/timlammers/2025/12/05/when-is-five-nights-at-freddys-2-coming-to-streaming/
#     ⏭ Skipped: not relevant or too short
#   (13/74) https://512pixels.net/2025/12/chamberlain-garage-door-locked-down/
#   ⚠️ Scrape error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#     ⏭ Skipped: not relevant or too short
#   (14/74) https://gizmodo.com/new-macbook-air-m4-is-now-cheaper-than-refurb-m2-amazon-liquidates-stock-after-black-friday-at-record-low-2000696077
#     ⏭ Skipped: not relevant or too short
#   (15/74) https://9to5mac.com/2025/12/05/us-lawmakers-ask-apple-google-about-iceblock-apps/
#   (16/74) https://tuned.ws/demo/
#     ⏭ Skipped: not relevant or too short
#   (17/74) http://electrek.co/2025/12/05/tesla-2025-holiday-update-few-cool-features/
#   (18/74) https://nypost.com/2025/12/05/us-news/mamdanis-plan-to-stop-homeless-encampment-sweeps-could-batter-real-estate-market-industry-leaders/
#     ⏭ Skipped: not relevant or too short
#   (19/74) https://www.techradar.com/phones/think-phones-are-boring-here-are-4-reasons-why-2025-was-a-big-year-for-smartphones-and-none-of-them-are-ai
#   (20/74) https://www.bavarianfootballworks.com/bayern-munich-bundesliga/152682/vfb-stuttgarts-sebastian-hoenes-knows-better-than-to-think-bayern-munich-is-out-of-form
#     ⏭ Skipped: not relevant or too short
#   (21/74) https://www.rawstory.com/gavin-newsom-2674374542/
#     ⏭ Skipped: not relevant or too short
#   (22/74) https://variety.com/2025/tv/news/pluribus-samba-schutte-what-koumba-wants-carol-discovery-1236600230/
#     ⏭ Skipped: not relevant or too short
#   (23/74) https://www.bbc.co.uk/news/articles/c8xdgwrrd0vo
#     ⏭ Skipped: not relevant or too short
#   (24/74) https://www.bbc.com/news/articles/c8xdgwrrd0vo
#     ⏭ Skipped: not relevant or too short
#   (25/74) https://www.abc.net.au/news/2025-12-06/victorian-miniature-railway-opens-harcourt-trains/106095804
#     ⏭ Skipped: not relevant or too short
#   (26/74) https://cardswire.usatoday.com/story/sports/nfl/cardinals/2025/12/05/rams-injury-report-davante-adams-to-play-vs-cardinals/87632429007/
#     ⏭ Skipped: not relevant or too short
#   (27/74) https://screenrant.com/best-hbo-max-shows-to-binge-weekend-december-5-7-2025/
#     ⏭ Skipped: not relevant or too short
#   (28/74) https://www.nature.com/articles/s41598-025-30809-5
#     ⏭ Skipped: not relevant or too short
#   (29/74) https://www.nature.com/articles/s41598-025-31372-9
#     ⏭ Skipped: not relevant or too short
#   (30/74) https://9to5mac.com/2025/12/05/india-mulls-mandatory-a-gps-activation/
#     ⏭ Skipped: not relevant or too short
#   (31/74) https://www.npr.org/2025/12/05/nx-s1-5622088/catastrophe-bonds-jamaica-hurricane-melissa
#     ⏭ Skipped: not relevant or too short
#   (32/74) https://www.freep.com/story/sports/mlb/tigers/2025/12/05/detroit-tigers-sign-drew-anderson-free-agency/87631781007/
#     ⏭ Skipped: not relevant or too short
#   (33/74) https://techcrunch.com/2025/12/05/ex-googlers-yoodli-triples-valuation-to-300m-with-ai-built-to-assist-not-replace-people/
#     ⏭ Skipped: not relevant or too short
#   (34/74) https://www.redmondpie.com/mac-users-can-get-christmas-ready-lights-and-snow-to-their-mac-with-this-app/
#     ⏭ Skipped: not relevant or too short
#   (35/74) https://cardswire.usatoday.com/story/sports/nfl/cardinals/2025/12/05/cardinals-injury-report-marvin-harrison-jr-trey-benson-ruled-out/87632166007/
#     ⏭ Skipped: not relevant or too short
#   (36/74) https://www.twincities.com/2025/12/05/gophers-likely-headed-to-rate-bowl/
#     ⏭ Skipped: not relevant or too short
#   (37/74) https://www.ibtimes.com/record-breaking-spotify-wrapped-2025-sees-200m-engage-500m-shares-day-3792059
#     ⏭ Skipped: not relevant or too short
#   (38/74) https://www.cnet.com/tech/mobile/your-holiday-survival-guide-to-finding-a-dead-or-stolen-iphone/
#   (39/74) https://bringatrailer.com/listing/2020-bmw-z4-6/
#     ⏭ Skipped: not relevant or too short
#   (40/74) https://dithering.passport.online/member/episode/alan-dye-leaves-apple
#     ⏭ Skipped: not relevant or too short
#   (41/74) https://www.theinformation.com/articles/silicon-valley-buzzing-apple-ceo-succession
#   ⚠️ Failed 403: https://www.theinformation.com/articles/silicon-valley-buzzing-apple-ceo-succession
#     ⏭ Skipped: not relevant or too short
#   (42/74) https://www.commondreams.org/news/newsom-oppose-wealth-tax-big-tent
#     ⏭ Skipped: not relevant or too short
#   (43/74) http://www.equinechronicle.com/nsba-tomorrows-horsemen-pass-the-baton/
#     ⏭ Skipped: not relevant or too short
#   (44/74) https://gizmodo.com/bluey-gold-pen-game-inspiration-joe-brumm-2000696293
#     ⏭ Skipped: not relevant or too short
#   (45/74) https://www.digitaljournal.com/entertainment/review-rockefeller-center-christmas-tree-lighting-ceremony-reba-mcentire-hosts-and-various-artists-perform/article
#     ⏭ Skipped: not relevant or too short
#   (46/74) https://www.bavarianfootballworks.com/bayern-munich-bundesliga/152580/bayern-munichs-vincent-kompany-understands-tough-slate-wont-overlook-vfb-stuttgart
#     ⏭ Skipped: not relevant or too short
#   (47/74) https://www.cinemablend.com/movies/after-watching-the-beatles-anthology-3-things-i-want-to-see-in-the-sam-mendes-biopics-1-thing-i-dont
#     ⏭ Skipped: not relevant or too short
#   (48/74) https://variety.com/2025/film/awards/jon-m-chu-wicked-for-good-saying-goodbye-leading-1236600710/
#     ⏭ Skipped: not relevant or too short
#   (49/74) https://www.redmondpie.com/apples-hypertension-sleep-apnea-and-hearing-health-features-come-to-new-countries/
#     ⏭ Skipped: not relevant or too short
#   (50/74) https://www.mactrast.com/2025/12/intels-rumored-return-to-apple-chip-production-could-extend-to-non-pro-iphones/
#   (51/74) https://www.macrumors.com/guide/macrumors-gift-guide/
#   (52/74) https://tidbits.com/2025/12/05/apple-executive-departures-could-signal-welcome-changes/
#   (53/74) https://cardswire.usatoday.com/story/sports/nfl/cardinals/2025/12/05/arizona-cardinals-injury-updates-from-jonathan-gannon-on-friday/87630882007/
#     ⏭ Skipped: not relevant or too short
#   (54/74) https://decider.com/2025/12/05/netflix-buying-warner-bros-what-does-it-mean/
#     ⏭ Skipped: not relevant or too short
#   (55/74) https://www.globenewswire.com/news-release/2025/12/05/3201006/0/en/Pixalate-Releases-Top-100-Connected-TV-CTV-Bundle-ID-Rankings-For-Global-Open-Programmatic-Ad-Spend-in-November-2025-Fawesome-Bundle-ID-is-No-1-on-Amazon-Fire-TV.html
#     ⏭ Skipped: not relevant or too short
#   (56/74) http://deadline.com/2025/12/sacker-entertainment-law-kirk-stambler-warner-bros-1236638029/
#     ⏭ Skipped: not relevant or too short
#   (57/74) https://9to5mac.com/2025/12/05/report-details-apple-departures-for-openai/
#   (58/74) https://www.androidheadlines.com/best-2-in-1-charging-stands
#     ⏭ Skipped: not relevant or too short
#   (59/74) https://macdailynews.com/2025/12/05/speculation-intensifies-on-apples-ceo-succession-plan-and-possible-contenders/
#   ⚠️ Scrape error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#     ⏭ Skipped: not relevant or too short
#   (60/74) https://mobilesyrup.com/2025/12/05/iphone-air-durable/
#   (61/74) https://fortune.com/2025/12/05/ai-labs-meta-deepseek-xai-bad-grades-existential-safety-index/
#     ⏭ Skipped: not relevant or too short
#   (62/74) https://www.apple.com/newsroom/2025/12/apple-announces-executive-transitions/
#   (63/74) https://www.androidheadlines.com/2025/12/iphone-16-is-the-best-selling-smartphone-globally-in-q3-2025.html
#   (64/74) https://www.notebookcheck.net/Red-Dead-Redemption-mobile-performance-tested-This-is-the-best-Apple-mobile-device-to-play-it-on.1178960.0.html
#   (65/74) https://techcrunch.com/video/aws-needs-you-to-believe-in-ai-agents/
#     ⏭ Skipped: not relevant or too short
#   (66/74) https://cardswire.usatoday.com/story/sports/nfl/cardinals/2025/12/05/marvin-harrison-injury-update-cardinals-wr-ruled-out-for-week-14/87630018007/
#     ⏭ Skipped: not relevant or too short
#   (67/74) https://www.animenewsnetwork.com/press-release/2025-12-05/nexon-closes-2025-with-two-new-top-rated-games/.231753
#   ⚠️ Failed 403: https://www.animenewsnetwork.com/press-release/2025-12-05/nexon-closes-2025-with-two-new-top-rated-games/.231753
#     ⏭ Skipped: not relevant or too short
#   (68/74) https://www.infomoney.com.br/mercados/bolsas-de-ny-fecham-em-alta-de-olho-em-expectativa-por-fed-e-acordo-netflix-warner/
#     ⏭ Skipped: not relevant or too short
#   (69/74) https://9to5mac.com/2025/12/05/car-keys-are-coming-to-the-wallet-app-for-13-new-vehicle-brands-soon/
#   (70/74) https://nypost.com/2025/12/05/lifestyle/top-2026-budget-travel-hotspots-revealed/
#     ⏭ Skipped: not relevant or too short
#   (71/74) https://sny.tv/articles/aaron-glenn-confident-jets-brady-cook-nfl-quarterback
#     ⏭ Skipped: not relevant or too short
#   (72/74) https://exclaim.ca/film/article/hollywood-defends-paul-dano-against-quentin-tarantino-s-insults
#     ⏭ Skipped: not relevant or too short
#   (73/74) https://nypost.com/2025/12/05/real-estate/architect-frank-gehry-dead-at-age-96/
#     ⏭ Skipped: not relevant or too short
#   (74/74) https://gizmodo.com/wikipedia-has-its-own-version-of-wrapped-now-but-theres-one-little-problem-2000696361
#     ⏭ Skipped: not relevant or too short
# ✅ AAPL: collected 15 valid scraped articles.
#
# 🔎 Fetching metadata for MSFT with query: Microsoft OR MSFT
#   Page 1 status: 200
#   Raw API articles: 99
#   After dropping missing URLs: 99
#   After removing bad domains: 90
#   After removing non-news/ad-like pages: 83
#   After title deduplication: 81
# 📰 Scraping articles for MSFT until we reach 30 valid pieces ...
#   (1/81) https://kevinmd.com/2025/12/a-lawyers-essential-checklist-for-physician-side-hustles-podcast.html
#   (2/81) https://www.daemonology.net/hn-daily/2025-12-05.html
#     ⏭ Skipped: not relevant or too short
#   (3/81) https://www.redmondpie.com/mac-users-can-get-christmas-ready-lights-and-snow-to-their-mac-with-this-app/
#     ⏭ Skipped: not relevant or too short
#   (4/81) https://www.theinformation.com/articles/silicon-valley-buzzing-apple-ceo-succession
#   ⚠️ Failed 403: https://www.theinformation.com/articles/silicon-valley-buzzing-apple-ceo-succession
#     ⏭ Skipped: not relevant or too short
#   (5/81) https://www.pymnts.com/artificial-intelligence-2/2025/ai-agents-can-cheat-when-operational-pressure-mounts-research-shows/
#   (6/81) https://www.redmondpie.com/apples-hypertension-sleep-apnea-and-hearing-health-features-come-to-new-countries/
#     ⏭ Skipped: not relevant or too short
#   (7/81) https://www.windowscentral.com/gaming/xbox/legendary-fallout-dev-making-xboxs-clockwork-revolution-teases-crazy-depth-and-a-feature-im-dying-to-see
#     ⏭ Skipped: not relevant or too short
#   (8/81) https://www.nextbigfuture.com/2025/12/xai-grok-4-2.html
#   (9/81) https://www.channelnewsasia.com/commentary/us-china-ai-race-chatgpt-deepseek-tech-5563681
#     ⏭ Skipped: not relevant or too short
#   (10/81) https://fortune.com/2025/12/05/ai-reasoning-energy-problem-data-centers-30-times-more-power/
#     ⏭ Skipped: not relevant or too short
#   (11/81) https://www.microsoft.com/en-us/security/blog/2025/12/05/microsoft-named-a-leader-in-the-2025-gartner-magic-quadrant-for-email-security/
#   (12/81) https://kotaku.com/game-awards-statue-elder-scrolls-6-geoff-keighley-2000651010
#     ⏭ Skipped: not relevant or too short
#   (13/81) https://pypi.org/project/microsoft-agents-m365copilot-beta/1.0.0rc12/
#     ⏭ Skipped: not relevant or too short
#   (14/81) https://pypi.org/project/microsoft-agents-m365copilot/1.2.0/
#   (15/81) https://www.aare.ai
#   (16/81) https://pypi.org/project/prefect-azure/0.4.7/
#     ⏭ Skipped: not relevant or too short
#   (17/81) https://ipwatchdog.com/2025/12/05/bites-barks-ny-times-sues-perplexity-ai-uspto-updates-mpep-reflect-desjardins-decision/
#   (18/81) http://9to5toys.com/2025/12/05/9to5toys-2025-gift-guide-best-pc-gaming-battlestation-upgrades/
#     ⏭ Skipped: not relevant or too short
#   (19/81) http://comicbook.com/gaming/list/5-games-from-the-2000s-you-forgot-were-awesome/
#     ⏭ Skipped: not relevant or too short
#   (20/81) https://www.windowscentral.com/microsoft/windows-11/microsoft-is-too-busy-with-ai-to-fix-windows-11s-design-so-developers-stepped-up
#     ⏭ Skipped: not relevant or too short
#   (21/81) https://www.thurrott.com/windows/330450/new-windows-11-insider-build-brings-file-explorer-and-settings-connectors-for-ai-agents
#     ⏭ Skipped: not relevant or too short
#   (22/81) https://kotaku.com/netflix-wb-batman-arkham-hogwarts-legacy-mortal-kombat-2000650918
#   (23/81) https://pypi.org/project/mcp-sharepoint-cert/
#     ⏭ Skipped: not relevant or too short
#   (24/81) https://www.windowscentral.com/microsoft/windows-11/microsoft-wants-to-fix-app-updates-on-windows-11-previews-new-update-orchestrator-platform-designed-make-updates-invisible
#     ⏭ Skipped: not relevant or too short
#   (25/81) https://www.irishtimes.com/media/2025/12/05/eurovision-fallout-over-israel-entry-potentially-leads-rte-down-slippery-slope/
#     ⏭ Skipped: not relevant or too short
#   (26/81) https://www.gematsu.com/2025/12/2xko-for-ps5-xbox-series-launches-in-january-2026
#     ⏭ Skipped: not relevant or too short
#   (27/81) https://www.foxnews.com/tech/fbi-warns-email-users-holiday-scams-surge
#     ⏭ Skipped: not relevant or too short
#   (28/81) https://www.realtor.com/advice/buy/data-centers-affordable-housing-henrico-county/
#   ⚠️ Failed 429: https://www.realtor.com/advice/buy/data-centers-affordable-housing-henrico-county/
#     ⏭ Skipped: not relevant or too short
#   (29/81) https://www.barchart.com/story/news/36481233/down-40-in-the-past-month-morgan-stanley-says-this-1-stock-is-key-to-the-future-of-ai
#   (30/81) https://www.pymnts.com/artificial-intelligence-2/2025/new-york-times-sues-perplexity-alleging-copyright-violations-and-damage-to-brand/
#     ⏭ Skipped: not relevant or too short
#   (31/81) https://www.mcsweeneys.net/articles/why-were-paywalling-our-family-christmas-card
#     ⏭ Skipped: not relevant or too short
#   (32/81) https://stratechery.com/2025/conflicts-consternation-and-code-red/
#   ⚠️ Scrape error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#     ⏭ Skipped: not relevant or too short
#   (33/81) https://thehackernews.com/2025/12/zero-click-agentic-browser-attack-can.html
#     ⏭ Skipped: not relevant or too short
#   (34/81) https://fortune.com/2025/12/05/mark-zuckerberg-metaverse-layoffs-cuts-facebook-rebrand/
#     ⏭ Skipped: not relevant or too short
#   (35/81) https://www.investopedia.com/stocks-have-rebounded-ahead-of-the-fed-meeting-but-the-market-s-leaders-are-changing-11862422
#   (36/81) https://www.techradar.com/pro/eu-launches-antitrust-investigation-into-metas-whatsapp-ai-access-policy
#     ⏭ Skipped: not relevant or too short
#   (37/81) https://www.newsweek.com/ai-backlash-openai-meta-friend-10807425
#   (38/81) https://fortune.com/2025/12/05/construction-workers-earning-six-figure-salaries-data-center-boom-ai-tech/
#     ⏭ Skipped: not relevant or too short
#   (39/81) https://screenrant.com/xbox-free-descenders-no-game-pass/
#     ⏭ Skipped: not relevant or too short
#   (40/81) https://apnews.com/article/internet-outage-cloudflare-zoom-linkedin-2ac314f7dcd112a63eb12b30afb74a33
#   (41/81) https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_e9c0ed81-781f-4620-8c61-4cd97a57a8be
#   ⚠️ Failed 401: https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_e9c0ed81-781f-4620-8c61-4cd97a57a8be
#     ⏭ Skipped: not relevant or too short
#   (42/81) https://www.gamesradar.com/games/gamesradar-goty-the-25-best-games-of-2025/
#     ⏭ Skipped: not relevant or too short
#   (43/81) https://www.wired.com/video/watch/chips-and-the-new-world-order/
#   ⚠️ Failed 404: https://www.wired.com/video/watch/chips-and-the-new-world-order/
#     ⏭ Skipped: not relevant or too short
#   (44/81) https://www.wired.com/video/watch/safeguarding-the-internets-future/
#   ⚠️ Failed 404: https://www.wired.com/video/watch/safeguarding-the-internets-future/
#     ⏭ Skipped: not relevant or too short
#   (45/81) https://www.wired.com/video/watch/teaching-ai-to-think-responsibly/
#   ⚠️ Failed 404: https://www.wired.com/video/watch/teaching-ai-to-think-responsibly/
#     ⏭ Skipped: not relevant or too short
#   (46/81) https://www.superpunch.net/2025/12/todays-news-and-jokes_01814340698.html
#   (47/81) https://wccftech.com/tsmc-scrambles-to-bring-advanced-packaging-to-the-us/
#     ⏭ Skipped: not relevant or too short
#   (48/81) https://www.foxnews.com/politics/aoc-silent-whether-she-amend-doomsday-climate-prediction-deadline-looms
#     ⏭ Skipped: not relevant or too short
#   (49/81) https://rollingout.com/2025/12/05/wall-street-protects-itself-ai-bubble/
#   (50/81) https://pypi.org/project/mcauth3/1.0.0/
#     ⏭ Skipped: not relevant or too short
#   (51/81) https://kotaku.com/fans-cant-believe-how-much-microsoft-is-selling-used-xbox-consoles-for-2000650923
#     ⏭ Skipped: not relevant or too short
#   (52/81) https://www.thurrott.com/a-i/330436/the-new-york-times-is-suing-perplexity-over-copyright-infringement-allegations
#     ⏭ Skipped: not relevant or too short
#   (53/81) https://economictimes.indiatimes.com/news/international/us/us-layoffs-2025-1-2-million-americans-laid-off-in-2025-as-job-cuts-hit-highest-level-since-the-covid-19-pandemic-is-ai-now-a-major-factor-in-u-s-job-cuts/articleshow/125792090.cms
#     ⏭ Skipped: not relevant or too short
#   (54/81) https://www.theregister.com/2025/12/05/microsoft_365_prices_up_2026/
#     ⏭ Skipped: not relevant or too short
#   (55/81) https://tidbits.com/watchlist/fantastical-4-1-5-cardhop-2-4-3/
#     ⏭ Skipped: not relevant or too short
#   (56/81) https://www.zdnet.com/article/i-bought-samsungs-1800-xr-headset-to-get-work-done-and-its-already-paying-off/
#   (57/81) https://www.gamesradar.com/hardware/handhelds/looks-like-the-asus-rog-ally-just-got-discontinued-but-its-at-least-down-to-a-price-id-pay/
#     ⏭ Skipped: not relevant or too short
#   (58/81) https://www.pcworld.com/article/3002304/microsoft-is-giving-windows-11s-run-command-a-fresh-look-30-years-later.html
#     ⏭ Skipped: not relevant or too short
#   (59/81) https://www.techpowerup.com/343738/microsoft-reportedly-boosting-xbox-production-output-linked-to-tentative-foxconn-vietnam-expansion
#     ⏭ Skipped: not relevant or too short
#   (60/81) https://www.siliconrepublic.com/business/agile-agentic-servicenow-lead-predicts-top-ai-trends-2026
#     ⏭ Skipped: not relevant or too short
#   (61/81) https://blogs.fangraphs.com/instagraphs/job-posting-boston-red-sox-2026-baseball-operations-summer-intern/
#     ⏭ Skipped: not relevant or too short
#   (62/81) https://techcrunch.com/2025/12/05/the-new-york-times-is-suing-perplexity-for-copyright-infringement/
#     ⏭ Skipped: not relevant or too short
#   (63/81) https://gizmodo.com/netflix-warner-bros-sale-theatrical-releases-2000696187
#     ⏭ Skipped: not relevant or too short
#   (64/81) https://www.nzherald.co.nz/nz/our-heroes-heralds-top-nzers-of-2025-in-news-sport-business-and-entertainment/C5SUWIFB5NHCRFYRBF2DBJ6CVM/
#   (65/81) https://fortune.com/2025/12/05/apple-executive-leadership-exodus-biggest-shakeup-since-steve-jobs-death/
#   (66/81) https://fortune.com/2025/12/05/apple-executive-leadership-exodus-biggest-shakeup-since-steve-jobs-death-tim-cook-lisa-jackson-kate-adams-john-giannandrea-jeff-williams/
#   (67/81) https://www.techtarget.com/searchsecurity/news/366636017/News-brief-RCE-flaws-persist-as-top-cybersecurity-threat
#   (68/81) https://martech.zone/best-platforms-to-build-ai-agents/
#     ⏭ Skipped: not relevant or too short
#   (69/81) https://www.globenewswire.com/news-release/2025/12/05/3200851/0/en/M365Con-net-Announces-Deep-Dive-Microsoft-Convention-Featuring-New-Sponsor-xSP.html
#   (70/81) https://post.rlsbb.to/windows-11-pro-26h1-build-28000-1199-preview/
#     ⏭ Skipped: not relevant or too short
#   (71/81) https://www.techtarget.com/searchsecurity/opinion/Security-highlights-from-AWS-reInvent
#   (72/81) https://pypi.org/project/agentic-fleet/0.6.7/
#     ⏭ Skipped: not relevant or too short
#   (73/81) https://www.techradar.com/pro/security/logitech-ceo-says-ai-devices-are-just-solutions-looking-for-a-problem
#   (74/81) https://www.theregister.com/2025/12/05/ai_is_not_a_bubble/
#     ⏭ Skipped: not relevant or too short
#   (75/81) https://www.redmondpie.com/eat-healthy-and-save-50-off-this-ninja-air-fryer-pro-4-in-1/
#     ⏭ Skipped: not relevant or too short
#   (76/81) https://www.businessinsider.com/meta-metaverse-reversal-tech-companies-reallocation-resources-2025-12
#     ⏭ Skipped: not relevant or too short
#   (77/81) https://www.globenewswire.com/news-release/2025/12/05/3200819/28124/en/Healthcare-Gamification-Market-Set-to-Double-be-2030-Reaching-27-74-Billion-Analysis-of-Emerging-Trends-Strategies-and-Investment-Opportunities.html
#     ⏭ Skipped: not relevant or too short
#   (78/81) https://www.rt.com/news/629078-us-europe-civilizational-erasure/
#     ⏭ Skipped: not relevant or too short
#   (79/81) https://www.pcworld.com/article/3002122/microsoft-announces-office-suite-price-hikes-for-2026.html
#   (80/81) https://hackread.com/criminal-ip-to-host-webinar-beyond-cves-from-visibility-to-action-with-asm/
#   (81/81) https://hackaday.com/2025/12/05/this-week-in-security-react-json-formatting-and-the-return-of-shai-hulud/
#     ⏭ Skipped: not relevant or too short
# ✅ MSFT: collected 24 valid scraped articles.
#
# 🔎 Fetching metadata for NVDA with query: NVIDIA OR NVDA
#   Page 1 status: 200
#   Page 2 status: 426
#   Raw API articles: 100
#   After dropping missing URLs: 100
#   After removing bad domains: 78
#   After removing non-news/ad-like pages: 73
#   After title deduplication: 73
# 📰 Scraping articles for NVDA until we reach 30 valid pieces ...
#   (1/73) https://pypi.org/project/aule-attention/0.2.0/
#   (2/73) https://pypi.org/project/aule-attention/
#     ⏭ Skipped: not relevant or too short
#   (3/73) https://www.notebookcheck.net/Aetina-introduces-Nvidia-RTX-Pro-Blackwell-embedded-GPU-MXM-modules.1178951.0.html
#   (4/73) https://observer.com/2025/12/google-ai-chip-tpu-nvidia-challenge/
#   (5/73) https://www.nextbigfuture.com/2025/12/xai-grok-4-2.html
#   (6/73) https://www.infomoney.com.br/mercados/bolsas-de-ny-fecham-em-alta-de-olho-em-expectativa-por-fed-e-acordo-netflix-warner/
#   (7/73) https://www.notebookcheck.net/Aaeon-Boxer-8651AI-Plus-Fanless-computer-is-powered-by-Nvidia-Jetson-Orin-NX.1178967.0.html
#   (8/73) https://www.notebookcheck.net/Aaeon-Boxer-8651AI-Plus-Fanless-mini-PC-is-powered-by-Nvidia-Jetson-Orin-NX.1178967.0.html
#   (9/73) https://www.thestreet.com/investing/cathie-woods-latest-move-is-alarming-for-big-stocks
#   ⚠️ Failed 403: https://www.thestreet.com/investing/cathie-woods-latest-move-is-alarming-for-big-stocks
#     ⏭ Skipped: not relevant or too short
#   (10/73) https://finance.yahoo.com/news/ouster-inc-oust-bull-case-200921356.html
#     ⏭ Skipped: not relevant or too short
#   (11/73) https://finance.yahoo.com/news/interactive-brokers-group-inc-ibkr-200705809.html
#     ⏭ Skipped: not relevant or too short
#   (12/73) https://www.techpowerup.com/343755/tuxedo-intros-gemini-17-gen-4-desktop-replacement-notebook-series
#     ⏭ Skipped: not relevant or too short
#   (13/73) https://oawlly.gumroad.com/l/transcribex
#   (14/73) https://pypi.org/project/nvalchemi-toolkit-ops/
#     ⏭ Skipped: not relevant or too short
#   (15/73) https://pypi.org/project/nvalchemi-toolkit-ops/0.1.0/
#     ⏭ Skipped: not relevant or too short
#   (16/73) https://finance.yahoo.com/news/bitcoins-2025-bull-run-over-193108824.html
#   (17/73) https://www.storagereview.com/review/hp-elitedesk-8-mini-g1a-review-small-form-factor-ryzen-ai-workstation
#   (18/73) https://finance.yahoo.com/news/doge-shib-still-hit-10-190115051.html
#   (19/73) https://www.barchart.com/story/news/36481480/amazon-just-released-its-graviton5-cpu-should-you-buy-sell-or-hold-amzn-stock-here
#   (20/73) https://www.barchart.com/story/news/36481233/down-40-in-the-past-month-morgan-stanley-says-this-1-stock-is-key-to-the-future-of-ai
#   (21/73) https://techcrunch.com/2025/12/05/aws-reinvent-was-an-all-in-pitch-for-ai-customers-might-not-be-ready/
#   (22/73) https://www.zdnet.com/home-and-office/home-entertainment/you-can-buy-the-77-inch-lg-b5-oled-for-50-off-right-now-and-i-highly-recommend-it/
#   (23/73) https://stratechery.com/2025/conflicts-consternation-and-code-red/
#   ⚠️ Scrape error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#     ⏭ Skipped: not relevant or too short
#   (24/73) https://www.techtarget.com/searchstorage/news/366636052/New-HPE-node-enriches-data-in-real-time-for-AI-pipelines
#   (25/73) https://developer.nvidia.com/blog/nvidia-kaggle-grandmasters-win-artificial-general-intelligence-competition/
#   (26/73) https://timesofindia.indiatimes.com/world/us/a-new-jaguar-spotted-in-arizona-points-to-progress-in-the-endangered-species-recovery/articleshow/125793811.cms
#     ⏭ Skipped: not relevant or too short
#   (27/73) https://www.gamespot.com/articles/a-5-million-gift-from-sega-saved-nvidia/1100-6536736/
#   (28/73) https://pypi.org/project/nvidia-nvjpeg/13.0.2.28/
#     ⏭ Skipped: not relevant or too short
#   (29/73) https://pypi.org/project/nvidia-nvfatbin/13.1.80/
#     ⏭ Skipped: not relevant or too short
#   (30/73) https://pypi.org/project/nvidia-npp/13.0.2.21/
#     ⏭ Skipped: not relevant or too short
#   (31/73) https://www.investopedia.com/stocks-have-rebounded-ahead-of-the-fed-meeting-but-the-market-s-leaders-are-changing-11862422
#   (32/73) https://pypi.org/project/nvidia-cusparse/12.7.2.19/
#     ⏭ Skipped: not relevant or too short
#   (33/73) https://pypi.org/project/nvidia-cusolver/12.0.7.41/
#     ⏭ Skipped: not relevant or too short
#   (34/73) https://pypi.org/project/nvidia-curand/10.4.1.34/
#     ⏭ Skipped: not relevant or too short
#   (35/73) https://pypi.org/project/nvidia-cufile/1.16.0.49/
#     ⏭ Skipped: not relevant or too short
#   (36/73) https://pypi.org/project/nvidia-cufft/12.1.0.31/
#   (37/73) https://pypi.org/project/nvidia-cublas/13.2.0.9/
#   (38/73) https://pypi.org/project/nvidia-nvtx/13.1.68/
#     ⏭ Skipped: not relevant or too short
#   (39/73) https://pypi.org/project/nvidia-cuda-nvrtc/13.1.80/
#     ⏭ Skipped: not relevant or too short
#   (40/73) https://pypi.org/project/nvidia-nvml-dev/13.1.68/
#   (41/73) https://www.tomshardware.com/tech-industry/artificial-intelligence/huawei-ascend-npu-roadmap-examined-company-targets-4-zettaflops-fp4-performance-by-2028-amid-manufacturing-constraints
#   (42/73) https://pypi.org/project/nvidia-cuda-cupti/13.1.75/
#   (43/73) https://pypi.org/project/nvidia-cuda-culibos/13.1.68/
#   (44/73) https://pypi.org/project/nvidia-cuda-runtime/13.1.80/
#   (45/73) https://pypi.org/project/nvidia-cuda-crt/13.1.80/
#   (46/73) https://www.newsweek.com/ai-backlash-openai-meta-friend-10807425
#   (47/73) https://timesofindia.indiatimes.com/etimes/trending/expert-warns-60-of-humanity-could-die-in-72-hours-if-north-korea-the-us-and-russia-trigger-wwiii/articleshow/125790546.cms
#     ⏭ Skipped: not relevant or too short
#   (48/73) https://www.zdnet.com/home-and-office/home-entertainment/the-lg-b5-is-a-great-entry-level-oled-tv-especially-at-50-off/
#   (49/73) https://dailycaller.com/2025/12/05/cnn-partnership-kalshi-prediction-markets-betting-breaking-news-events/
# ✅ NVDA: collected 30 valid scraped articles.
#
# 🔎 Fetching metadata for JPM with query: JPMorgan OR JPM
#   Page 1 status: 200
#   Raw API articles: 97
#   After dropping missing URLs: 97
#   After removing bad domains: 34
#   After removing non-news/ad-like pages: 29
#   After title deduplication: 27
# 📰 Scraping articles for JPM until we reach 30 valid pieces ...
#   (1/27) https://cointelegraph.com/news/msci-exclusion-btc-firms-is-unworkable-strive-ceo
#   (2/27) https://nypost.com/2025/12/05/opinion/climate-change-doom-and-gloomers-are-finally-bowing-out-showing-that-common-sense-prevailed/
#   (3/27) https://economictimes.indiatimes.com/news/international/global-trends/how-netflix-won-hollywoods-biggest-prize-warner-bros-discovery/articleshow/125798462.cms
#     ⏭ Skipped: not relevant or too short
#   (4/27) https://www.livemint.com/companies/news/citi-is-worth-the-sum-of-its-parts-for-first-time-in-seven-years-11764970779746.html
#   (5/27) http://www.newsbtc.com/bitcoin-news/bitcoin-volatility-on-microstrategy/
#   (6/27) https://financialpost.com/globe-newswire/jpmorgan-announces-cash-distributions-for-the-jpmorgan-etfs-14
#   (7/27) https://financialpost.com/news/netflixs-loan-warner-bros-biggest-ever
#   (8/27) https://decrypt.co/351142/cantor-slashes-strategy-price-target-remains-long-term-bullish-bitcoin
#   (9/27) https://www.thestreet.com/crypto/trading/ripple-ceo-predicts-bitcoin-to-hit-180k
#   ⚠️ Failed 403: https://www.thestreet.com/crypto/trading/ripple-ceo-predicts-bitcoin-to-hit-180k
#     ⏭ Skipped: not relevant or too short
#   (10/27) https://finance.yahoo.com/news/venture-global-vg-continued-fall-182900591.html
#   (11/27) https://www.ibtimes.com/epstein-island-speed-dial-phone-reveals-five-new-names-files-3792032
#   (12/27) https://rollingout.com/2025/12/05/wall-street-protects-itself-ai-bubble/
#   (13/27) https://finance.yahoo.com/news/netflix-lines-59-billion-debt-125547191.html
#   (14/27) https://therealdeal.com/miami/2025/12/05/sergio-busquets-selling-waterfront-fort-lauderdale-house/
#   (15/27) https://nypost.com/2025/12/05/business/state-street-still-using-dei-to-curry-favor-with-leftist-state-officials/
#   (16/27) https://www.coindesk.com/markets/2025/12/04/jpmorgan-retains-gold-linked-usd170k-bitcoin-target-despite-recent-plunge
#   (17/27) https://finance.yahoo.com/news/m-61-being-invited-retire-124100766.html
#   (18/27) https://economictimes.indiatimes.com/news/international/us/apple-executive-mass-exodus-why-ai-chief-policy-boss-design-head-all-walked-out-in-3-days/articleshow/125788601.cms
#     ⏭ Skipped: not relevant or too short
#   (19/27) https://www.cnbc.com/2025/12/05/londons-canary-wharf-gains-momentum-as-visa-jpmorgan-lease-space.html
#   (20/27) https://fortune.com/2025/12/05/four-key-questions-about-openai-vs-google-the-high-stakes-tech-matchup-of-2026/
#   (21/27) https://ritholtz.com/2025/12/10-friday-am-reads-478/
#   (22/27) https://finance.yahoo.com/news/wall-street-races-cut-risk-113000304.html
#   (23/27) https://www.businessinsider.com/apple-stock-price-retail-investor-analysis-ai-trade-magnificent-seven-2025-12
#   (24/27) https://cryptonews.com/news/strategys-ability-to-hold-bitcoin-may-shape-btcs-path-to-170k-jpmorgan/
#   ⚠️ Failed 403: https://cryptonews.com/news/strategys-ability-to-hold-bitcoin-may-shape-btcs-path-to-170k-jpmorgan/
#     ⏭ Skipped: not relevant or too short
#   (25/27) https://bitcoinist.com/strategy-forced-to-sell-bitcoin-bitwise-cio/
#   (26/27) https://www.ndtvprofit.com/ipos/meesho-ipo-check-subscription-on-final-day-gmp-details-and-more
#   (27/27) https://www.coinspeaker.com/eth-to-62000-tom-lee-is-ultra-bullish-but-traders-watch-these-numbers/
# ✅ JPM: collected 23 valid scraped articles.
#
# 🔎 Fetching metadata for GS with query: "Goldman Sachs" OR GS
#   Page 1 status: 200
#   Raw API articles: 99
#   After dropping missing URLs: 99
#   After removing bad domains: 68
#   After removing non-news/ad-like pages: 65
#   After title deduplication: 64
# 📰 Scraping articles for GS until we reach 30 valid pieces ...
#   (1/64) https://cointelegraph.com/news/msci-exclusion-btc-firms-is-unworkable-strive-ceo
#   (2/64) https://nypost.com/2025/12/05/opinion/climate-change-doom-and-gloomers-are-finally-bowing-out-showing-that-common-sense-prevailed/
#   (3/64) https://neurosciencenews.com/astrocytes-acetylcholine-smoking-30021/
#     ⏭ Skipped: not relevant or too short
#   (4/64) https://cryptobriefing.com/clear-street-crypto-treasury-underwriter-ipo/
#     ⏭ Skipped: not relevant or too short
#   (5/64) https://www.livemint.com/companies/news/citi-is-worth-the-sum-of-its-parts-for-first-time-in-seven-years-11764970779746.html
#   (6/64) http://www.etf.com/sections/podcasts/etf-zoo-staggering-flows-driving-2-speed-etf-market?utm_source=yahoo-finance&amp;utm_medium=rss&amp;utm_campaign=yahoo-finance-rss
#   ⚠️ Failed 403: http://www.etf.com/sections/podcasts/etf-zoo-staggering-flows-driving-2-speed-etf-market?utm_source=yahoo-finance&amp;utm_medium=rss&amp;utm_campaign=yahoo-finance-rss
#     ⏭ Skipped: not relevant or too short
#   (7/64) https://finance.yahoo.com/news/fluence-flnc-soars-17-7-182937752.html
#   (8/64) https://finance.yahoo.com/news/gold-on-pace-for-weekly-win-as-momentum-drives-historic-2025-rally-172922240.html
#   (9/64) https://www.blessyouboys.com/detroit-tigers-prospects-amp-minor-leagues/83754/detroit-tigers-prospects-top-ten-scouting-baseball-america
#     ⏭ Skipped: not relevant or too short
#   (10/64) https://www.bbc.co.uk/sounds/play/p0mlv9rh
#     ⏭ Skipped: not relevant or too short
#   (11/64) https://www.thestreet.com/investing/stocks/goldman-sachs-issues-micron-prediction-ahead-of-earnings
#   ⚠️ Failed 403: https://www.thestreet.com/investing/stocks/goldman-sachs-issues-micron-prediction-ahead-of-earnings
#     ⏭ Skipped: not relevant or too short
#   (12/64) https://rollingout.com/2025/12/05/wall-street-protects-itself-ai-bubble/
#   (13/64) https://www.backingthepack.com/nc-state-basketball/35844/nc-state-welcomes-unc-asheville
#     ⏭ Skipped: not relevant or too short
#   (14/64) https://www.sportingnews.com/us/soccer/news/england-world-cup-draw-2026-group-schedule/8a00a2f453c846bc7de0af41
#     ⏭ Skipped: not relevant or too short
#   (15/64) https://www.bostonherald.com/2025/12/05/top-albums/
#     ⏭ Skipped: not relevant or too short
#   (16/64) https://www.rte.ie/news/business/2025/1205/1547498-us-consumer-spending/
#   (17/64) http://commercialobserver.com/2025/12/cre-interest-rates-cap-rates-fed-trump-nyu/
#   (18/64) https://www.newsminer.com/news/local_news/gvea-submits-rate-case-filing/article_b049f799-15c0-48fa-a98c-cfe91134f44e.html
#     ⏭ Skipped: not relevant or too short
#   (19/64) https://road.cc/content/news/israel-premier-tech-lost-out-political-reasons-says-ds-317181
#     ⏭ Skipped: not relevant or too short
#   (20/64) https://www.barchart.com/story/news/36476936/google-is-riding-the-ai-wave-higher-but-the-real-winner-of-gemini-3-is-this-stock
#   (21/64) https://www.hospitalitynet.org/opinion/4130086.html
#   (22/64) https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0338100
#     ⏭ Skipped: not relevant or too short
#   (23/64) https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0337894
#     ⏭ Skipped: not relevant or too short
#   (24/64) https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0338341
#     ⏭ Skipped: not relevant or too short
#   (25/64) https://www.businessinsider.com/gen-z-career-advice-goldman-sachs-equity-chief-2025-12
#   (26/64) https://www.rap-up.com/article/polo-g-and-g-herbo-drop-gangsta-graduation-video
#     ⏭ Skipped: not relevant or too short
#   (27/64) https://www.naftemporiki.gr/english/2042783/banks-next-stop-is-new-york/
#   (28/64) https://economictimes.indiatimes.com/news/international/us/oracle-debt-spirals-toward-2008-era-danger-zones-morgan-stanley-sounds-the-alarm-is-orcl-still-a-buy-before-earnings/articleshow/125789209.cms
#     ⏭ Skipped: not relevant or too short
#   (29/64) https://finance.yahoo.com/news/wall-street-races-cut-risk-113000304.html
#   (30/64) https://www.slashgear.com/2041334/gm-chevy-454-pontiac-455-engine-differences/
#     ⏭ Skipped: not relevant or too short
#   (31/64) https://finance.yahoo.com/personal-finance/banking/article/best-cd-rates-today-friday-december-5-2025-110020000.html
#   (32/64) https://www.cnbc.com/2025/12/05/yieldstreet-investors-losses-willow-wealth-rebrand.html
#   (33/64) https://www.businessinsider.com/citadel-cto-personally-calls-candidates-to-recruit-talent-2025-12
#   (34/64) https://economictimes.indiatimes.com/markets/stocks/news/5-deeper-stress-signals-for-nifty-investors-even-as-rbi-cuts-rates-on-goldilocks-phase/articleshow/125784730.cms
#     ⏭ Skipped: not relevant or too short
#   (35/64) https://fortune.com/2025/12/05/return-to-office-design-workplace-gensler-ray-yuen/
#   (36/64) https://www.sportingnews.com/us/soccer/news/australia-world-cup-draw-2026-group-schedule-socceroos/1a4b7da49af41e01878aeb90
#     ⏭ Skipped: not relevant or too short
#   (37/64) https://finance.yahoo.com/news/luxury-stocks-look-ready-stronger-080000392.html
#   (38/64) https://beincrypto.com/dollar-stablecoins-rmb-china-regulation-2025/
#   (39/64) https://www.football-espana.net/2025/12/05/barcelona-president-fuels-outrage-with-latest-comments-about-real-madrid-they-represent
#   (40/64) https://finance.yahoo.com/news/toyota-announces-major-milestone-journey-073500348.html
#   (41/64) https://markets.businessinsider.com/news/stocks/goldman-ai-bubble-public-tech-stocks-private-markets-2025-12
#   (42/64) https://iasbaba.com/2025/12/daily-current-affairs-ias-upsc-prelims-and-mains-exam-5th-december/
#     ⏭ Skipped: not relevant or too short
#   (43/64) https://www.javacodegeeks.com/2025/12/foundations-and-implications-of-generative-ai-reshaping-creativity-and-automation-across-industries.html
#   (44/64) https://oilprice.com/Latest-Energy-News/World-News/India-Steps-Up-Purchases-of-Sanctions-Free-Russian-Crude.html
#   (45/64) https://dailycaller.com/2025/12/05/opinion-trump-demonstrates-power-of-energy-policy-david-blackmon/
#   (46/64) https://finance.yahoo.com/news/big-shift-ai-stock-trade-060031741.html
#   (47/64) https://economictimes.indiatimes.com/markets/stocks/news/us-affordability-squeeze-eases-slightly-as-key-delinquency-metrics-stabilize/articleshow/125781712.cms
#     ⏭ Skipped: not relevant or too short
#   (48/64) https://economictimes.indiatimes.com/markets/stocks/news/global-hedge-funds-outpace-major-indexes-with-15-returns-in-2025/articleshow/125780846.cms
#     ⏭ Skipped: not relevant or too short
#   (49/64) https://financialpost.com/pmn/business-pmn/copper-rises-to-record-on-bullish-citi-outlook-supply-concerns
#   (50/64) https://finance.yahoo.com/news/jim-cramer-coinbase-sell-way-034528646.html
#   (51/64) https://www.sportingnews.com/ca/soccer/news/canada-world-cup-draw-2026-group-schedule/0d75b591642c942b3529ab69
#     ⏭ Skipped: not relevant or too short
#   (52/64) https://freerepublic.com/focus/f-chat/4356002/posts
#   (53/64) https://finance.yahoo.com/news/sony-group-corporation-sony-buy-031029076.html
# ✅ GS: collected 30 valid scraped articles.
#
# 🔎 Fetching metadata for XOM with query: "Exxon Mobil" OR XOM
#   Page 1 status: 200
#   Raw API articles: 97
#   After dropping missing URLs: 97
#   After removing bad domains: 86
#   After removing non-news/ad-like pages: 79
#   After title deduplication: 73
# 📰 Scraping articles for XOM until we reach 30 valid pieces ...
#   (1/73) https://www.rigzone.com/news/wire/chevron_gorgon_partners_ok_2b_to_drill_for_more_gas-05-dec-2025-182466-article/
#   (2/73) https://freerepublic.com/focus/f-chat/4356011/posts
#   (3/73) https://www.globenewswire.com/news-release/2025/12/04/3200106/28124/en/Europe-Hydrogen-Market-Report-2025-Significant-Opportunities-As-It-Aims-for-10mtpa-Production-and-Import-by-2030.html
#     ⏭ Skipped: not relevant or too short
#   (4/73) https://www.rigzone.com/news/chevron_expects_2026_budget_to_be_on_lower_end_of_guidance-04-dec-2025-182453-article/
#   (5/73) https://www.rt.com/news/628924-pornhub-owner-lukoil-acquisition/
#   (6/73) https://fortune.com/2025/12/04/nyt-dealbook-summit-ceos-ai-business-case-bubble/
#     ⏭ Skipped: not relevant or too short
#   (7/73) https://economictimes.indiatimes.com/industry/energy/oil-gas/how-an-oil-pipeline-battle-shows-the-us-gaining-sway-in-iraq/articleshow/125759146.cms
#     ⏭ Skipped: not relevant or too short
#   (8/73) https://oilprice.com/Energy/Natural-Gas/Drill-Baby-Drill-Europe-Aims-To-Reduce-Reliance-on-US-LNG.html
#   (9/73) https://oilprice.com/Latest-Energy-News/World-News/Ex-Pornhub-Owner-Reportedly-Interested-In-Lukoil-Assets.html
#   (10/73) https://financialpost.com/pmn/business-pmn/chinas-petrochemicals-boom-escalating-fears-of-global-glut
#   (11/73) https://www.barchart.com/story/news/36412945/stock-indexes-push-higher-on-strength-in-chip-makers
#   (12/73) https://financialpost.com/pmn/business-pmn/sec-chief-wants-to-boost-ipos-by-easing-rules-for-small-firms
#   (13/73) https://www.barchart.com/story/news/36380179/is-slb-stock-underperforming-the-dow
#   (14/73) https://www.rigzone.com/news/wire/cpc_halts_black_sea_oil_loading_amid_ukrainian_attacks-01-dec-2025-182418-article/
#   (15/73) https://www.rigzone.com/news/totalenergies_completes_bonga_exit-01-dec-2025-182415-article/
#   (16/73) https://www.lawyersgunsmoneyblog.com/2025/11/the-corruption-of-american-foreign-policy
#   (17/73) https://www.rt.com/news/628682-turkiye-condemns-ukrainian-drone-attacks/
#   (18/73) https://www.bbc.com/news/articles/cp9ky5z2gx0o
#   (19/73) https://financialpost.com/pmn/business-pmn/cpc-reports-halts-in-black-sea-oil-loading-after-new-attack
#   (20/73) https://finance.yahoo.com/news/invested-10k-exxon-mobil-stock-130143238.html
#   (21/73) https://www.thehindubusinessline.com/markets/commodities/cpc-says-oil-exports-halted-at-black-sea-terminal-equipment-heavily-damaged-by-drones/article70338158.ece
#   (22/73) https://www.barchart.com/story/news/36361590/stocks-settle-higher-as-chip-makers-and-energy-producers-rally
#   (23/73) https://www.barchart.com/story/news/36360717/is-chevron-corporation-stock-underperforming-the-s-p-500
#   (24/73) https://www.rigzone.com/news/wire/petrobras_slumps_after_unveiling_109b_spending_plan-28-nov-2025-182410-article/
#   (25/73) https://financialpost.com/pmn/business-pmn/petrobras-trims-five-year-plan-to-109-billion-on-low-prices
#   (26/73) https://oilprice.com/Energy/Energy-General/Cutting-Edge-Space-Tech-Uncovers-Major-Lithium-Target-in-Quebec.html
#   (27/73) https://www.globenewswire.com/news-release/2025/11/26/3195362/0/en/Green-Hydrogen-Market-Size-to-Worth-USD-413-20-Bn-by-2035.html
#   (28/73) https://www.barchart.com/story/news/36326605/3-highest-yielding-dividend-aristocrats-to-buy-today
#   (29/73) https://www.globenewswire.com/news-release/2025/11/26/3195145/28124/en/Liquified-Petroleum-Gas-Market-Forecasts-Report-2025-2030-Urbanization-Industrial-Growth-Environmental-Regulations-and-Emerging-Use-in-the-Shipping-Sector-are-Accelerating-Growth.html
#   (30/73) https://www.barchart.com/story/news/36315334/google-is-winning-the-ai-race-by-stealing-exxon-s-business-model-here-s-how
#   (31/73) https://www.barchart.com/story/news/36304908/is-exxon-mobil-stock-underperforming-the-s-p-500
#   (32/73) https://finance.yahoo.com/news/exxonmobil-xom-buys-40-stake-224926317.html
#   (33/73) https://www.naftemporiki.gr/english/2037703/shiamishis-to-n-helleniq-energy-expands-to-geneva/
# ✅ XOM: collected 30 valid scraped articles.
#
# 🔎 Fetching metadata for TSLA with query: Tesla OR TSLA
#   Page 1 status: 200
#   Raw API articles: 98
#   After dropping missing URLs: 98
#   After removing bad domains: 79
#   After removing non-news/ad-like pages: 71
#   After title deduplication: 69
# 📰 Scraping articles for TSLA until we reach 30 valid pieces ...
#   (1/69) https://www.livemint.com/companies/news/spacex-may-sell-insider-shares-at-historic-800-billion-valuation-will-the-elon-musk-company-float-ipo-soon-11764987059202.html
#   (2/69) http://electrek.co/2025/12/05/tesla-2025-holiday-update-few-cool-features/
#   (3/69) https://chinadigitaltimes.net/2025/12/netizen-voices-as-sino-japanese-tensions-rise-tourism-is-treated-like-a-chamberpot-a-disposable-tool/
#   (4/69) https://www.nextbigfuture.com/2025/12/xai-grok-4-2.html
#   (5/69) https://techcrunch.com/2025/12/05/feds-find-more-complaints-of-teslas-fsd-running-red-lights-and-crossing-lanes/
#   (6/69) http://electrek.co/2025/12/05/podcast-tesla-texting-and-driving-trump-kills-mpg-aptera-update-and-more/
#   (7/69) https://nypost.com/2025/12/05/us-news/d4vd-at-1-of-googles-trending-musicians-of-2025/
#   (8/69) https://www.thestreet.com/investing/cathie-woods-latest-move-is-alarming-for-big-stocks
#   ⚠️ Failed 403: https://www.thestreet.com/investing/cathie-woods-latest-move-is-alarming-for-big-stocks
#     ⏭ Skipped: not relevant or too short
#   (9/69) https://www.ozbargain.com.au/node/938675
#   (10/69) https://rollingout.com/2025/12/05/spacex-100-million-bitcoin-coinbase/
#   (11/69) https://finance.yahoo.com/news/doge-shib-still-hit-10-190115051.html
#   (12/69) https://fortune.com/2025/12/05/elon-musk-tesla-owners-texting-driving-full-self-driving-illegal/
#   (13/69) https://www.iphoneincanada.ca/2025/12/05/spacex-just-filed-starlink-mobile-a-new-wireless-era-is-coming/
#   (14/69) https://www.barchart.com/story/news/36481308/tesla-netflix-and-on-semiconductor-3-unusually-active-cash-secured-put-options-to-sell-now
#   (15/69) https://www.iphoneincanada.ca/2025/12/05/rivian-adding-native-apple-and-google-phone-keys-later-this-month/
#   (16/69) https://gizmodo.com/elon-musk-slapped-with-140-million-fine-over-deceptive-blue-checks-on-x-2000696215
#   (17/69) https://www.investopedia.com/stocks-have-rebounded-ahead-of-the-fed-meeting-but-the-market-s-leaders-are-changing-11862422
#   (18/69) https://www.newser.com/story/379901/consumer-reports-these-10-car-brands-are-tops.html
#     ⏭ Skipped: not relevant or too short
#   (19/69) https://www.bmwblog.com/2025/12/05/subaru-beats-bmw-2025-consumer-reports/
#     ⏭ Skipped: not relevant or too short
#   (20/69) https://wccftech.com/tsmc-scrambles-to-bring-advanced-packaging-to-the-us/
#   (21/69) https://cryptobriefing.com/proshares-leveraged-etfs-withdrawal/
#   (22/69) https://punchng.com/?p=2002481
#   (23/69) https://www.mensjournal.com/gear/china-is-dumping-cheap-gas-cars-heres-what-that-means-for-you
#   ⚠️ Failed 403: https://www.mensjournal.com/gear/china-is-dumping-cheap-gas-cars-heres-what-that-means-for-you
#     ⏭ Skipped: not relevant or too short
#   (24/69) https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_4fd409e7-7035-4b28-bf0d-8a1f80f7b9c0
#   ⚠️ Failed 401: https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_4fd409e7-7035-4b28-bf0d-8a1f80f7b9c0
#     ⏭ Skipped: not relevant or too short
#   (25/69) https://nypost.com/2025/12/05/business/musks-x-hit-with-140m-fine-in-europe-over-deceptive-blue-checkmark-transparency-issues/
#   (26/69) https://techcrunch.com/2025/12/05/energy-storage-industry-set-aggressive-goals-for-2025-and-already-crushed-them/
#   (27/69) https://wccftech.com/exynos-2600-yet-to-enter-mass-production-despite-samsung-announcing-it/
#   (28/69) https://www.rawstory.com/alternet-posts/trump-tech-bros-bannon/
#   (29/69) http://electrek.co/2025/12/05/kia-vision-meta-turismo-previews-potential-ev8/
#   (30/69) https://www.globenewswire.com/news-release/2025/12/05/3200781/0/en/Physical-AI-Market-to-Hit-USD-49-73-Billion-by-2033-Owing-to-Advances-in-Robotics-and-Real-World-Intelligent-Systems-Research-by-SNS-Insider.html
#     ⏭ Skipped: not relevant or too short
#   (31/69) https://finance.yahoo.com/news/chatgpt-thinks-alphabet-stock-price-142620746.html
#   (32/69) https://finance.yahoo.com/news/chatgpt-thinks-tesla-stock-price-141750329.html
#   (33/69) https://bringatrailer.com/listing/2018-tesla-model-x-2/
#   (34/69) https://newatlas.com/motorcycles/yadea-comes-to-europe/
#   (35/69) https://news.sky.com/story/eu-hands-120m-fine-to-elon-musks-x-for-breaking-social-media-rules-13479732
#   (36/69) https://cointelegraph.com/news/doge-to-bitcoin-elon-musk-orange-pill
# ✅ TSLA: collected 30 valid scraped articles.
#
# ✅ Final news_df after global dedup and filters: (182, 12)
#   ticker    source_name  \
# 0   AAPL  Hip-Hop Wired
# 1   AAPL     pymnts.com
# 2   AAPL        9to5Mac
# 3   AAPL       Electrek
# 4   AAPL      TechRadar
# 5   AAPL           CNET
# 6   AAPL   Mactrast.com
# 7   AAPL      MacRumors
# 8   AAPL        TidBITS
# 9   AAPL        9to5Mac
#
#                                                                                                           title  \
# 0                                               A Selfless Pass Ends One Of The Greatest Records In NBA History
# 1                                      Dozens of Apple Employees Have Moved to OpenAI and Meta in Recent Months
# 2                                        House panel questions Apple on apps used to track immigration officers
# 3                                                  Tesla announces 2025 holiday update with a few cool features
# 4  Think phones are boring? Here are 4 reasons why 2025 was a big year for smartphones, and none of them are AI
# 5                                                Your Holiday Survival Guide to Finding a Dead or Stolen iPhone
# 6                             Intel’s Rumored Return to Apple Chip Production Could Extend to ‘Non-Pro’ iPhones
# 7                                                                             MacRumors 2025 Holiday Gift Guide
# 8                                                       Apple Executive Departures Could Signal Welcome Changes
# 9                               New report sheds a bit more light on who at Apple has been departing for OpenAI
#
#    scraped_len
# 0         3152
# 1         3009
# 2         2559
# 3         6255
# 4         5664
# 5         3971
# 6         1452
# 7        16709
# 8         9290
# 9         2772

# %% [markdown]
# ### 2.4 Data limitation
#
# Even after expanding the search to up to 10 pages of NewsAPI results per ticker (so up to 100 raw items) and using a relatively lenient length threshold (250 characters), some firms still end up with fewer than 30 valid scraped articles.
#
# This is not a coding error but a property of the underlying news supply:
#
# - A non-trivial share of URLs come from paywalled or low-value aggregators such as The Fly, Biztoc, and Slashdot, which I intentionally exclude.
# - Many remaining links are software pages, app listings, or shopping “deals”, which are removed by my non-news and ad-like keyword filters.
# - Some URLs return very little readable `<p>` content (e.g., login walls or short blurbs), and these are dropped by the body-text quality test.
#
# In these cases, I keep all valid articles that pass my filters and treat the smaller sample size as a **data limitation**. I deliberately prioritize text quality and topical relevance over mechanically forcing every firm to have exactly 30 articles, which would dilute the downstream sentiment and topic analysis.
#
# Also, despite implementing multiple filters—such as removing ad-related keywords, excluding restricted sources, and deduplicating near-identical titles—the dataset still contains some articles that include promotional content or marginally relevant information. These cases highlight an inherent challenge in news scraping: many financial news aggregators blend editorial content with sponsored posts, app installation pages, and SEO-optimized summaries. While our filtering pipeline reduces noise substantially, a small fraction of “quasi-news” inevitably remains. Capturing cleaner, more semantically relevant text would require more advanced methods such as HTML structure–aware extraction, source-level whitelisting, or supervised relevance classification to more reliably distinguish genuine news reporting from automated or low-quality content.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import pandas as pd # Import pandas to use isinstance(news_df, pd.DataFrame)

# Check if news_df is defined and is a DataFrame before attempting to save it
if 'news_df' in globals() and isinstance(news_df, pd.DataFrame):
    news_df.to_csv('/content/drive/MyDrive/news_df.csv', index=False)
    print("✅ news_df successfully saved to Google Drive.")
else:
    print("⚠️ news_df is not defined or is not a DataFrame. Please ensure the data collection step (e.g., cell '5tyuY2txfSfD') has been run successfully before saving.")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 3. Sentiment Analysis with VADER
#
# After building the cleaned news corpus, I use VADER to measure the tone of each article.
# VADER is a rule-based sentiment model that produces a compound score in [-1, 1], which
# is particularly suitable for short, informal, and finance-related text.
#
# I apply VADER to the scraped article bodies, then aggregate sentiment to the ticker level,
# computing the average sentiment and the share of positive/negative/neutral articles for each firm.
# This provides a simple proxy for overall “market tone” toward each company.

# %%
# VADER Sentiment for Scraped Articles → Aggregate → Plot

# Install packages (only needed the first time)
# !pip -q install --upgrade nltk
# !pip install plotly

import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd
import plotly.express as px
import plotly.io as pio


# --- IMPORTANT: reset Plotly template/renderer to avoid Template error ---
# Some environments set pio.templates.default incorrectly (to a Template object).
# Here we force it back to a simple named template.
pio.templates.default = None
px.defaults.template = None
pio.templates.default = "plotly"
px.defaults.template = "plotly"
# In Colab the default renderer is usually fine; no need to override.
# If you really want, you can uncomment the next line:
# pio.renderers.default = "colab"

# Ensure VADER lexicon
nltk.download('vader_lexicon')

# Initialize analyzer
sia = SentimentIntensityAnalyzer()

# Load news_df if not already loaded (e.g., after runtime restart)
if 'news_df' not in locals() and 'news_df' not in globals():
    try:
        news_df = pd.read_csv('/content/drive/MyDrive/news_df.csv')
        print("✅ news_df loaded from Google Drive.")
    except FileNotFoundError:
        raise FileNotFoundError("news_df.csv not found in Google Drive. Please run the scraping steps first.")

# Ensure scraped_text exists
if "scraped_text" not in news_df.columns:
    raise ValueError("news_df missing 'scraped_text'. Run the scraping step first.")

# 1. Compute article-level VADER sentiment
print("Computing VADER compound sentiment for scraped_text ...")
news_df["vader_compound"] = news_df["scraped_text"].fillna("").apply(compound_score)

# 2. Optional sentiment labels
POS, NEG = 0.05, -0.05
news_df["sentiment_label"] = news_df["vader_compound"].apply(
    lambda c: "pos" if c > POS else ("neg" if c < NEG else "neu")
)

print("\nExample rows:")
display(news_df[["ticker", "title", "vader_compound", "sentiment_label"]].head())

# 3. Aggregate sentiment at the ticker level
ticker_sent = (
    news_df.groupby("ticker")
    .agg(
        mean_vader=("vader_compound", "mean"),
        n_articles=("scraped_text", "count"),
        pct_pos=("sentiment_label", lambda s: (s == "pos").mean()),
        pct_neg=("sentiment_label", lambda s: (s == "neg").mean()),
        pct_neu=("sentiment_label", lambda s: (s == "neu").mean()),
    )
    .reset_index()
)

# Round for readability
ticker_sent["mean_vader"] = ticker_sent["mean_vader"].round(3)
ticker_sent["pct_pos"] = (ticker_sent["pct_pos"] * 100).round(1)
ticker_sent["pct_neg"] = (ticker_sent["pct_neg"] * 100).round(1)
ticker_sent["pct_neu"] = (ticker_sent["pct_neu"] * 100).round(1)

print("\nTicker-level sentiment summary:")
display(ticker_sent)

# 4. Visualization: bar chart of average sentiment by ticker
fig = px.bar(
    ticker_sent,
    x="ticker",
    y="mean_vader",
    color="mean_vader",
    color_continuous_scale="RdYlGn",
    hover_data=["n_articles", "pct_pos", "pct_neg", "pct_neu"],
    title="Average VADER Sentiment by Ticker (Scraped News Articles)",
    labels={
        "mean_vader": "Average Sentiment (Compound)",
        "ticker": "Stock Ticker",
    },
)

fig.update_layout(
    xaxis_title="Ticker",
    yaxis_title="Mean Compound Sentiment",
    title_font_size=18,
    template="plotly",  # explicitly set a safe template here as well
)

fig.show()
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (6.5.0)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Computing VADER compound sentiment for scraped_text ...
#
# Example rows:
#   ticker  \
# 0   AAPL
# 1   AAPL
# 2   AAPL
# 3   AAPL
# 4   AAPL
#
#                                                                                                           title  \
# 0                                               A Selfless Pass Ends One Of The Greatest Records In NBA History
# 1                                      Dozens of Apple Employees Have Moved to OpenAI and Meta in Recent Months
# 2                                        House panel questions Apple on apps used to track immigration officers
# 3                                                  Tesla announces 2025 holiday update with a few cool features
# 4  Think phones are boring? Here are 4 reasons why 2025 was a big year for smartphones, and none of them are AI
#
#    vader_compound sentiment_label
# 0          0.9792             pos
# 1          0.7964             pos
# 2          0.4462             pos
# 3          0.9992             pos
# 4          0.9969             pos
# Ticker-level sentiment summary:
#   ticker  mean_vader  n_articles  pct_pos  pct_neg  pct_neu
# 0   AAPL       0.755          15     93.3      6.7      0.0
# 1     GS       0.859          30     93.3      6.7      0.0
# 2    JPM       0.722          23     87.0     13.0      0.0
# 3   MSFT       0.525          24     75.0     25.0      0.0
# 4   NVDA       0.481          30     70.0     30.0      0.0
# 5   TSLA       0.460          30     73.3     23.3      3.3
# 6    XOM       0.620          30     80.0     20.0      0.0
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="b407b439-add2-4548-ae88-90201480b650" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b407b439-add2-4548-ae88-90201480b650")) {                    Plotly.newPlot(                        "b407b439-add2-4548-ae88-90201480b650",                        [{"customdata":{"dtype":"f8","bdata":"","shape":"7, 4"},"hovertemplate":"Stock Ticker=%{x}\u003cbr\u003eAverage Sentiment (Compound)=%{marker.color}\u003cbr\u003en_articles=%{customdata[0]}\u003cbr\u003epct_pos=%{customdata[1]}\u003cbr\u003epct_neg=%{customdata[2]}\u003cbr\u003epct_neu=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"KVyPwvUo6D+wcmiR7XzrP7TIdr6fGuc\u002fzczMzMzM4D9iEFg5tMjeP3E9CtejcN0\u002f16NwPQrX4z8="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["AAPL","GS","JPM","MSFT","NVDA","TSLA","XOM"],"xaxis":"x","y":{"dtype":"f8","bdata":"KVyPwvUo6D+wcmiR7XzrP7TIdr6fGuc\u002fzczMzMzM4D9iEFg5tMjeP3E9CtejcN0\u002f16NwPQrX4z8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"pa ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Figure: Average VADER Sentiment by Ticker — Interpretation**
#
# The figure shows the average sentiment score for news articles associated with each company. Apple, Goldman Sachs, and JPMorgan receive the most positive tone, indicating strong market confidence. Tech firms such as Microsoft, Tesla, and NVIDIA show more mixed sentiment, reflecting uncertainty around AI growth and regulatory pressure. ExxonMobil sits in the middle, consistent with the typically balanced tone of energy-sector news. These cross-industry differences set up the clustering patterns seen later in the two-factor “Sentiment × Topic Exposure” analysis.

# %% [markdown]
# ## 4. Text Cleaning & Preprocessing
#
# Before topic modeling, all scraped article text is normalized so that TF-IDF reflects meaningful economic language rather than noise. The pipeline includes lowercasing, URL removal, tokenization, stopword filtering, and lemmatization. I also removed company names, advertisement boilerplate, and repetitive footer text to avoid contaminating topic exposure and prevent artificial clustering driven by firm-specific jargon.

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')

english_stopwords = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

# Remove company names to avoid contaminating thematic signals
ticker_words = [
    "aapl","apple","msft","microsoft","nvda","nvidia",
    "tsla","tesla","xom","exxon","mobil","gs","goldman",
    "sachs","jpm","jpmorgan","morgan"
]

# text cleaning
def clean_text(text):
    if text is None:
        return ""

    text = text.lower()
    text = re.sub(r"http\S+|www\.\S+", " ", text)
    text = re.sub(r"[^a-z\s]", " ", text)

    tokens = nltk.word_tokenize(text)

    tokens = [tok for tok in tokens if tok not in ticker_words]
    tokens = [tok for tok in tokens if tok not in english_stopwords and len(tok) > 2]
    tokens = [lemmatizer.lemmatize(tok) for tok in tokens]

    return " ".join(tokens)

news_df["scraped_text_clean"] = news_df["scraped_text"].astype(str).apply(clean_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## 5. Dictionary-Based Topic Modeling (Macro, AI, Energy)
#
# Rather than using LDA—which is noisy, random, and hard to interpret—I apply a dictionary-based topic model. This approach is deterministic, transparent, and fully customizable: each topic is defined by curated keyword lists representing macro, AI, and energy themes. The method aligns with industry practice (e.g., Bloomberg and FactSet keyword tagging) and produces stable, interpretable exposure scores for each company. Below are the lists of words I prepared for better topic modeling.

# %%
topic_macro = [
    "inflation","fed","interest","rate","rates","growth","economy","economic",
    "recession","employment","jobs","gdp","policy","central","market","markets",
    "bond","bonds","yield","credit","debt","tightening","easing"
]

topic_ai = [
    "ai","artificial","intelligence","model","models","algorithm","compute",
    "computing","semiconductor","semiconductors","chip","chips","gpu","gpus",
    "cloud","neural","deep","training","automation","data","machine","learning"
]

topic_energy = [
    "oil","gas","energy","barrel","production","opec","supply","demand",
    "commodity","refinery","natural","pipeline","petroleum","crude","brent","wti"
]

topic_dicts = {
    "macro": topic_macro,
    "ai": topic_ai,
    "energy": topic_energy
}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Build TF-IDF matrix on cleaned text
tfidf_vec = TfidfVectorizer(stop_words="english", max_df=0.85, min_df=2)
X = tfidf_vec.fit_transform(news_df["scraped_text_clean"].fillna(""))

# Create vocabulary index for fast lookup
vocab = tfidf_vec.get_feature_names_out()
vocab_index = {w: i for i, w in enumerate(vocab)}

# Initialize topic exposure container
topic_scores = {"ticker": news_df["ticker"]}

# Compute topic exposure by summing TF-IDF values of dictionary words
for name, words in topic_dicts.items():
    idx = [vocab_index[w] for w in words if w in vocab_index]
    exposure = X[:, idx].sum(axis=1).A.flatten() if idx else np.zeros(X.shape[0])
    topic_scores[name] = exposure

# Convert to DataFrame
topic_exposure_df = pd.DataFrame(topic_scores)

# Aggregate exposures to ticker level
ticker_topic_exposure = (
    topic_exposure_df.groupby("ticker")[["macro","ai","energy"]].mean().reset_index()
)

ticker_topic_exposure
# Out:
#   ticker     macro        ai    energy
# 0   AAPL  0.021147  0.087470  0.019265
# 1     GS  0.244133  0.101890  0.109043
# 2    JPM  0.171673  0.060858  0.035503
# 3   MSFT  0.108823  0.177761  0.021155
# 4   NVDA  0.099519  0.230909  0.021664
# 5   TSLA  0.098018  0.075481  0.053477
# 6    XOM  0.161362  0.044129  0.461309

# %% [markdown]
# ## 6. Combining Sentiment + Topic Exposure
#
# I merge firm-level VADER sentiment with dictionary-based topic exposure to create a two-factor view of each company. Topic exposure is computed by summing TF-IDF weights for macro, AI, and energy keywords, then aggregating to the ticker level.
#
# Combining these scores with average sentiment produces a matrix linking **market tone** and **policy relevance**. Plotting the two dimensions reveals how firms cluster across themes, showing which sectors attract positive narratives and which are tied to policy-sensitive topics.

# %%
# Merge sentiment and topic exposure into a single DataFrame
twofactor_df = ticker_sent.merge(ticker_topic_exposure, on="ticker", how="inner")
display(twofactor_df)

import plotly.express as px

# Scatter: sentiment vs. macro exposure
px.scatter(
    twofactor_df, x="macro", y="mean_vader", text="ticker",
    size="n_articles", color="mean_vader",
    color_continuous_scale="RdYlGn",
    title="Sentiment × Macro Topic Exposure"
).show()

# Scatter: sentiment vs. AI exposure
px.scatter(
    twofactor_df, x="ai", y="mean_vader", text="ticker",
    size="n_articles", color="mean_vader",
    color_continuous_scale="RdYlGn",
    title="Sentiment × AI Topic Exposure"
).show()

# Scatter: sentiment vs. energy exposure
px.scatter(
    twofactor_df, x="energy", y="mean_vader", text="ticker",
    size="n_articles", color="mean_vader",
    color_continuous_scale="RdYlGn",
    title="Sentiment × Energy Topic Exposure"
).show()
# Out:
#   ticker  mean_vader  n_articles  pct_pos  pct_neg  pct_neu     macro  \
# 0   AAPL       0.755          15     93.3      6.7      0.0  0.021147
# 1     GS       0.859          30     93.3      6.7      0.0  0.244133
# 2    JPM       0.722          23     87.0     13.0      0.0  0.171673
# 3   MSFT       0.525          24     75.0     25.0      0.0  0.108823
# 4   NVDA       0.481          30     70.0     30.0      0.0  0.099519
# 5   TSLA       0.460          30     73.3     23.3      3.3  0.098018
# 6    XOM       0.620          30     80.0     20.0      0.0  0.161362
#
#          ai    energy
# 0  0.087470  0.019265
# 1  0.101890  0.109043
# 2  0.060858  0.035503
# 3  0.177761  0.021155
# 4  0.230909  0.021664
# 5  0.075481  0.053477
# 6  0.044129  0.461309
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="d28837b4-f99b-4272-a5e2-872ca94c5463" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d28837b4-f99b-4272-a5e2-872ca94c5463")) {                    Plotly.newPlot(                        "d28837b4-f99b-4272-a5e2-872ca94c5463",                        [{"hovertemplate":"macro=%{x}\u003cbr\u003emean_vader=%{marker.color}\u003cbr\u003en_articles=%{marker.size}\u003cbr\u003eticker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"KVyPwvUo6D+wcmiR7XzrP7TIdr6fGuc\u002fzczMzMzM4D9iEFg5tMjeP3E9CtejcN0\u002f16NwPQrX4z8="},"coloraxis":"coloraxis","size":{"dtype":"i1","bdata":"Dx4XGB4eHg=="},"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["AAPL","GS","JPM","MSFT","NVDA","TSLA","XOM"],"x":{"dtype":"f8","bdata":"TbneKIanlT81g8IexD\u002fPP4cXHBBf+cU\u002fEX\u002fMFdTbuz+1bXc2Gnq5P2KRjI63F7k\u002fIzJnsYSnxD8="},"xaxis":"x","y":{"dtype":"f8","bdata":"KVyPwvUo6D+wcmiR7XzrP7TIdr6fGuc\u002fzczMzMzM4D9iEFg5tMjeP3E9CtejcN0\u002f16NwPQrX4z8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="9277b7aa-b5dc-42c2-bc84-cf92a085cdb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9277b7aa-b5dc-42c2-bc84-cf92a085cdb7")) {                    Plotly.newPlot(                        "9277b7aa-b5dc-42c2-bc84-cf92a085cdb7",                        [{"hovertemplate":"ai=%{x}\u003cbr\u003emean_vader=%{marker.color}\u003cbr\u003en_articles=%{marker.size}\u003cbr\u003eticker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"KVyPwvUo6D+wcmiR7XzrP7TIdr6fGuc\u002fzczMzMzM4D9iEFg5tMjeP3E9CtejcN0\u002f16NwPQrX4z8="},"coloraxis":"coloraxis","size":{"dtype":"i1","bdata":"Dx4XGB4eHg=="},"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["AAPL","GS","JPM","MSFT","NVDA","TSLA","XOM"],"x":{"dtype":"f8","bdata":"ycT8zWZktj9J9Q2ndRW6PzF5YofUKK8\u002fIQWG\u002fN\u002fAxj9cmuJKbY7NP+w2CtC8UrM\u002ffAmmwQuYpj8="},"xaxis":"x","y":{"dtype":"f8","bdata":"KVyPwvUo6D+wcmiR7XzrP7TIdr6fGuc\u002fzczMzMzM4D9iEFg5tMjeP3E9CtejcN0\u002f16NwPQrX4z8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6"," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="30be2c32-bdae-4dfd-96e5-8fd063aba3ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("30be2c32-bdae-4dfd-96e5-8fd063aba3ef")) {                    Plotly.newPlot(                        "30be2c32-bdae-4dfd-96e5-8fd063aba3ef",                        [{"hovertemplate":"energy=%{x}\u003cbr\u003emean_vader=%{marker.color}\u003cbr\u003en_articles=%{marker.size}\u003cbr\u003eticker=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"f8","bdata":"KVyPwvUo6D+wcmiR7XzrP7TIdr6fGuc\u002fzczMzMzM4D9iEFg5tMjeP3E9CtejcN0\u002f16NwPQrX4z8="},"coloraxis":"coloraxis","size":{"dtype":"i1","bdata":"Dx4XGB4eHg=="},"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["AAPL","GS","JPM","MSFT","NVDA","TSLA","XOM"],"x":{"dtype":"f8","bdata":"R5+S6lC6kz8sd2TENeq7P2959ZdsLaI\u002fqyMGk8GplT+6V1t1Ky+WP+ZLm\u002fNWYas\u002fwhhU\u002fxaG3T8="},"xaxis":"x","y":{"dtype":"f8","bdata":"KVyPwvUo6D+wcmiR7XzrP7TIdr6fGuc\u002fzczMzMzM4D9iEFg5tMjeP3E9CtejcN0\u002f16NwPQrX4z8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 7. Interpretation of Topic Exposure × Sentiment Results
#
# ### 7.1 Macro Topic Exposure
#
# Across the sample, macro exposure remains relatively low for all companies, but the variations help explain differences in how firms are discussed in news coverage.
#
# * **Goldman Sachs (GS)** shows **high sentiment and slightly elevated macro exposure**, reflecting frequent mentions of markets, interest rates, and monetary policy — consistent with its role in global finance.
# * **JPMorgan (JPM)** also exhibits **positive sentiment with moderate macro references**, likely driven by commentary on interest rates, deposits, and consumer credit.
# * **Tech firms (AAPL, MSFT, NVDA, TSLA)** cluster toward **lower macro exposure**, meaning their coverage is dominated more by product cycles and innovation rather than macroeconomics. Among them, **Tesla (TSLA)** shows the **lowest sentiment**, reflecting more negative news tone despite low macro discussion.
#
# **Interpretation:**
# Financial firms naturally appear in macroeconomic narratives and receive more positive tone, while tech firms’ sentiment seems unrelated to macro exposure—suggesting their sentiment variation is driven by sector-specific factors, not by the macro cycle.
#
#
# ### 7.2 AI Topic Exposure
#
# AI exposure varies widely across firms and produces a clear pattern:
#
# * **Nvidia (NVDA)** and **Microsoft (MSFT)** show **high AI exposure**, aligning with their roles in GPUs and cloud AI ecosystems.
#
#   * NVDA has moderately positive sentiment; MSFT’s sentiment is more neutral–negative, reflecting issues like AI safety, regulation, or competitive pressures.
# * **Apple (AAPL)** and **Goldman Sachs (GS)** have **moderate AI exposure but very high sentiment**, meaning AI-related discussions for these firms tend to be positive or peripheral.
# * **Tesla (TSLA)** has **low AI exposure and the lowest sentiment**, suggesting that recent Tesla coverage is driven more by operational and management-related narratives than AI.
#
# **Interpretation:**
# AI exposure does **not** guarantee positive sentiment. Instead, it appears that firms at the center of the AI boom experience both optimism and skepticism, while firms with only peripheral AI mentions enjoy more positive tone. This supports concerns that markets may be increasingly sensitive to an **AI “hype cycle”** — a potential policy-relevant signal.
#
#
# ### 7.3 Energy Topic Exposure
#
# Energy exposure sharply distinguishes ExxonMobil (XOM) from the rest:
#
# * **XOM** shows **very high energy exposure**, as expected, with mixed sentiment reflecting volatile oil markets, production constraints, and policy debates about climate transitions.
# * All other firms cluster near zero, indicating that energy-related language does not appear in their coverage in a meaningful way.
#
# Sentiment among non-energy firms thus reflects factors unrelated to the energy sector.
#
# **Interpretation:**
# The energy topic is highly concentrated in XOM, confirming the validity of dictionary-based exposure. Its moderate sentiment reinforces that commodity-driven industries receive more policy-charged, less uniformly positive coverage.
#
#
# ### 7.4 Cross-Topic Insight
#
# Taken together, the topic–sentiment scatterplots reveal clear patterns across sectors.
#
# Financial firms exhibit both high sentiment and moderate macro exposure, suggesting confidence in financial stability narratives and generally positive news tone around banks.
#
# In contrast, tech firms show lower sentiment combined with widely varying levels of AI exposure, indicating early skepticism about the speed and sustainability of AI-driven growth despite heavy media attention.
#
# Energy-related exposure is concentrated almost entirely in ExxonMobil, whose sentiment reflects the volatility of commodity cycles and ongoing climate policy tensions rather than broader market narratives.

# %% [markdown]
# ## 8. Policy Implication
#
# The patterns from section 7 also carry important policy implications.
#
# The relatively **high sentiment toward financial institutions** suggests that markets currently view the macroeconomic environment—interest rates, liquidity conditions, and regulatory stability—as predictable and well-managed. **Policymakers should continue monitoring systemic risk but may not need immediate intervention.**
#
# In contrast, the **lower sentiment attached to major tech firms**, even as their exposure to AI-related language rises, signals growing public uncertainty about the pace of AI deployment, data governance, and the potential for over-investment in emerging technologies. **This highlights a policy need for clearer AI regulation, transparency standards, and competition oversight to prevent bubbles and protect consumers.**
#
# Meanwhile, the **energy sector’s concentrated topic exposure**—centered almost entirely on ExxonMobil—shows that sentiment is closely tied to commodity cycles and climate-related debates. **Policymakers should anticipate that shifts in environmental regulation, carbon pricing, or geopolitical energy events will disproportionately influence market expectations for this sector.**
#
# Overall, the joint topic–sentiment results point toward a regulatory environment in which **AI governance**, **financial stability**, and **energy transition policy** are increasingly interconnected and influential for market confidence.

# %% [markdown]
# ## 9. Summary of Project and Key Innovations
#
# This project examines how news sentiment differs across seven major U.S. companies and how this sentiment interacts with policy-relevant themes such as macroeconomics, artificial intelligence, and energy. I built a full pipeline that collects, cleans, analyzes, and visualizes real financial news using web scraping, VADER sentiment analysis, TF-IDF weighting, and custom topic modeling.
#
# A key innovation is the **enhanced data-collection system**: expanding search keywords beyond tickers, multi-pass scraping to guarantee 30 usable articles per firm, filtering out irrelevant pages and low-quality domains (e.g., paywalls, ads), and removing duplicated headlines. This produces a much higher-quality dataset than standard API queries.
#
# In preprocessing, I added **domain-specific cleaning**—removing company names to avoid topic leakage, applying custom stopwords, and filtering articles heuristically. This ensures cleaner linguistic signals and avoids artificially inflated topic scores.
#
# Methodologically, I moved beyond LDA and implemented a **dictionary-based topic model** with three policy-aligned themes (macro, AI, energy). This approach is stable, interpretable, and consistent with how professional financial data vendors classify news.
#
# Finally, I combined sentiment and topic exposure into **two-factor scatterplots**, revealing clear sector patterns: financial firms cluster with strong sentiment and higher macro relevance, while tech firms show weaker sentiment despite high AI exposure.
#
# Together, these innovations—**improved scraping, targeted filtering, customized cleaning, policy-aligned topic modeling, and two-factor visualization**—form a robust, transparent, and policy-relevant text-analysis pipeline.
